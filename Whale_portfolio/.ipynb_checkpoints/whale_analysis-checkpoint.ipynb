# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from datetime import date
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
#read Data
whale_returns = pd.read_csv("whale_returns.csv", index_col = "Date", parse_dates=True)

# %%
print(type(whale_returns.index))
print(type(whale_returns[whale_returns.columns[0]][0]))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# <class 'numpy.float64'>

# %%
# Reading whale returns
whale_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# ...

# %%
# Count nulls
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
whale_returns = whale_returns.dropna()

# %%
# Count nulls
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algo_returns = pd.read_csv("algo_returns.csv", index_col = "Date", parse_dates=True)

# %%
algo_returns
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %%
# Count nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns = algo_returns.dropna()
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
tsx_60_returns = pd.read_csv("sp_tsx_history.csv", index_col = "Date", parse_dates=True)

# %%
# Check Data Types
print(type(tsx_60_returns.index))
print(type(tsx_60_returns[tsx_60_returns.columns[0]][0]))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# <class 'str'>

# %%
tsx_60_returns
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99
# ...                ...
# 2019-12-20  $17,118.44
# 2019-12-23  $17,128.71
# 2019-12-24  $17,180.15
# 2019-12-27  $17,168.21
# 2019-12-30  $17,098.56
#
# [1818 rows x 1 columns]

# %%
# Fix Data Types
tsx_60_returns['Close'] = pd.to_numeric(tsx_60_returns['Close'].str.replace('[\$\,]', '', regex=True))

# %%
tsx_60_returns
# Out:
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99
# ...              ...
# 2019-12-20  17118.44
# 2019-12-23  17128.71
# 2019-12-24  17180.15
# 2019-12-27  17168.21
# 2019-12-30  17098.56
#
# [1818 rows x 1 columns]

# %%
print(type(tsx_60_returns[tsx_60_returns.columns[0]][0]))
# Out:
# <class 'numpy.float64'>

# %%
# Calculate Daily Returns
tsx_daily_returns = tsx_60_returns.pct_change().dropna()

# %%
tsx_daily_returns
# Out:
#                Close
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709
# ...              ...
# 2019-12-20  0.003188
# 2019-12-23  0.000600
# 2019-12-24  0.003003
# 2019-12-27 -0.000695
# 2019-12-30 -0.004057
#
# [1817 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
tsx_daily_returns = tsx_daily_returns.rename(columns={'Close': 'TSX_60'})

# %%
tsx_daily_returns
# Out:
#               TSX_60
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709
# ...              ...
# 2019-12-20  0.003188
# 2019-12-23  0.000600
# 2019-12-24  0.003003
# 2019-12-27 -0.000695
# 2019-12-30 -0.004057
#
# [1817 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
combined_data = whale_returns.join(algo_returns.join(tsx_daily_returns)).dropna()

# %%
combined_data
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
sns.set(font_scale = 1)
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(16,10))
sns.lineplot(ax=ax,data = combined_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Plot daily returns of all portfolios
sns.set_style("whitegrid")
fig= plt.figure(figsize=(20,20))
a = 3  
b = 3  
c = 1  
for i in combined_data:
    plt.subplot(a, b, c)
    plt.title('{}'.format(i))
    plt.xlabel('Date')
    sns.lineplot(data = combined_data, x=combined_data.index, y=combined_data[i].values)
    sns.despine()
    c = c+1
plt.show()
plt.tight_layout()

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (combined_data+1).cumprod()

# Plot cumulative returns
sns.set(font_scale = 2)
sns.set_style("whitegrid")
fig, ax= plt.subplots(figsize=(20,20))
sns.lineplot(ax=ax, data=cumulative_returns, linewidth = 2.5)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
sns.set()
sns.set_style("whitegrid")
fig, ax= plt.subplots(figsize=(20,20))
sns.boxplot(ax=ax, data=combined_data)
plt.legend(labels= [x for x in combined_data.columns], fontsize = 20)

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolio
portfolios_std = combined_data.std()
portfolios_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# TSX_60                         0.007034
# dtype: float64

# %%
tsx_std = portfolios_std['TSX_60']

riskier_portfolios = []
for i in portfolios_std.to_dict():
    if portfolios_std.to_dict()[i] > tsx_std:
        riskier_portfolios.append(i)

# %%
riskier_portfolios
# Out:
# ['SOROS FUND MANAGEMENT LLC',
#  'TIGER GLOBAL MANAGEMENT LLC',
#  'BERKSHIRE HATHAWAY INC',
#  'Algo 1',
#  'Algo 2']

# %%
riskier_portfolios_df = combined_data[riskier_portfolios]

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
riskier_portfolios_df
# Out:
#             SOROS FUND MANAGEMENT LLC  TIGER GLOBAL MANAGEMENT LLC  \
# Date
# 2015-03-03                  -0.001266                    -0.000496
# 2015-03-04                   0.002230                    -0.002534
# 2015-03-05                   0.004016                     0.002355
# 2015-03-06                  -0.007905                    -0.008481
# 2015-03-09                   0.000582                     0.005843
# ...                               ...                          ...
# 2019-04-25                  -0.000285                    -0.005153
# 2019-04-26                   0.008149                     0.012355
# 2019-04-29                   0.001254                     0.006251
# 2019-04-30                  -0.001295                    -0.000259
# 2019-05-01                  -0.005847                    -0.007936
#
#             BERKSHIRE HATHAWAY INC    Algo 1    Algo 2
# Date
# 2015-03-03               -0.006569 -0.001942 -0.000949
# ...

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = portfolios_std*np.sqrt(252)

# %%
annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# Algo 2                         0.132177
# TSX_60                         0.111664
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_data_rolling_120 = combined_data.rolling(window=21).std()

# Plot the rolling standard deviation
sns.set()
sns.set_style("whitegrid")
fig, ax= plt.subplots(figsize=(20,20))
sns.lineplot(ax=ax, data=combined_data_rolling_120, linewidth = 2.5)
plt.legend(labels= [x for x in combined_data.columns], fontsize = 20)

# %%
combined_data_rolling_120.dropna()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-31                   0.005764            0.004641
# 2015-04-01                   0.005744            0.004467
# 2015-04-02                   0.005749            0.004502
# 2015-04-06                   0.005792            0.004492
# 2015-04-07                   0.005452            0.004385
# ...                               ...                 ...
# 2019-04-25                   0.004145            0.005572
# 2019-04-26                   0.004117            0.005649
# 2019-04-29                   0.004123            0.005374
# 2019-04-30                   0.004199            0.005408
# 2019-05-01                   0.004271            0.005009
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-31                     0.006731                0.007108  0.007866
# 2015-04-01                     0.006750                0.007005  0.007886
# ...

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
portfolios_corr = combined_data.corr()

# Display de correlation matrix
sns.set()
sns.set_style("whitegrid")
mask = np.triu(np.ones_like(portfolios_corr, dtype=bool))
fig, ax= plt.subplots(figsize=(20,20))
cmap = sns.color_palette("mako", as_cmap=True)
sns.heatmap(ax=ax, data=portfolios_corr, cmap=cmap, mask=mask, vmax=1, vmin=-1, square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
berkshire_cov = combined_data.cov()['BERKSHIRE HATHAWAY INC'].mean()

# Calculate variance of S&P TSX
tsx_var = combined_data['TSX_60'].var()
# Computing beta
res = stats.linregress(combined_data['TSX_60'].values,combined_data['BERKSHIRE HATHAWAY INC'].values)
beta = res.slope
# Plot beta trend
rolling_covariance = combined_data['BERKSHIRE HATHAWAY INC'].rolling(window=30).cov(combined_data['TSX_60'])
rolling_variance = combined_data['TSX_60'].rolling(window=30).var()
rolling_beta = rolling_covariance / rolling_variance
sns.set(font_scale = 2)
sns.set_style("whitegrid")
fig, ax= plt.subplots(figsize=(20,20))
p = sns.lineplot(ax=ax, data=rolling_beta,linewidth = 2.5).set_title('30 Day Rolling Beta')

# %%
beta
# Out:
# 1.0160439091063656

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
combined_data_ewma = combined_data.ewm(span=21).mean()

# %%
combined_data_ewma
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.000565           -0.000674
# 2015-03-05                   0.001827            0.001063
# 2015-03-06                  -0.000964           -0.000267
# 2015-03-09                  -0.000593            0.000810
# ...                               ...                 ...
# 2019-04-25                   0.001590           -0.000272
# 2019-04-26                   0.002186            0.000585
# 2019-04-29                   0.002102            0.000779
# 2019-04-30                   0.001793            0.000507
# 2019-05-01                   0.001098            0.000339
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.001563               -0.000921 -0.005424
# ...

# %%
sns.set(font_scale = 2)
sns.set_style("whitegrid")
fig, ax= plt.subplots(figsize=(20,20))
sns.lineplot(ax=ax, data=combined_data_ewma, linewidth = 2.5)
plt.legend(labels= [x for x in combined_data.columns], fontsize = 20)

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
#Assuming risk free rate of 2%
sharpe_ratios = ((combined_data.mean() * 252) - 0.02) / (combined_data.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.125755
# PAULSON & CO.INC.             -0.728033
# TIGER GLOBAL MANAGEMENT LLC   -0.260224
# BERKSHIRE HATHAWAY INC         0.368813
# Algo 1                         1.325497
# Algo 2                         0.245505
# TSX_60                         0.016441
# dtype: float64

# %%
sharpe_df = pd.DataFrame(sharpe_ratios).reset_index().rename(columns={'index':'Portfolio', 0:'Sharpe_Ratio'})

# %%
# Visualize the sharpe ratios as a bar plot
sns.set(font_scale = 2)
sns.set_style("whitegrid")
fig, ax= plt.subplots(figsize=(20,20))
sns.barplot(ax=ax, x='Portfolio', y='Sharpe_Ratio', data=sharpe_df)
plt.legend(labels= [x for x in combined_data.columns], fontsize = 20)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Both Algo 1 and algo 2 do outperform the S&P TSX 60

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P TSX 60 index.
#
# * `SHOP` - [Shopify Inc](https://en.wikipedia.org/wiki/Shopify)
#
# * `OTEX` - [Open Text Corporation](https://en.wikipedia.org/wiki/OpenText)
#
# * `L` - [Loblaw Companies Limited](https://en.wikipedia.org/wiki/Loblaw_Companies)

# %%
# Reading data from 1st stock
shop_returns = pd.read_csv("shop_historical.csv", index_col = "Date", parse_dates=True)
shop_returns
# Out:
#            Symbol   Close
# Date
# 2018-01-02   SHOP  132.06
# 2018-01-03   SHOP  135.15
# 2018-01-04   SHOP  137.46
# 2018-01-05   SHOP  137.26
# 2018-01-08   SHOP  139.51
# ...           ...     ...
# 2019-12-20   SHOP  513.22
# 2019-12-23   SHOP  511.62
# 2019-12-24   SHOP  525.39
# 2019-12-27   SHOP  534.76
# 2019-12-30   SHOP  517.79
#
# [501 rows x 2 columns]

# %%
# Reading data from 2nd stock
otex_returns = pd.read_csv("otex_historical.csv", index_col = "Date", parse_dates=True)
otex_returns
# Out:
#            Symbol  Close
# Date
# 2018-01-02   OTEX  43.58
# 2018-01-03   OTEX  43.07
# 2018-01-04   OTEX  42.91
# 2018-01-05   OTEX  42.57
# 2018-01-08   OTEX  42.16
# ...           ...    ...
# 2019-12-20   OTEX  58.68
# 2019-12-23   OTEX  57.89
# 2019-12-24   OTEX  57.44
# 2019-12-27   OTEX  57.70
# 2019-12-30   OTEX  57.19
#
# [501 rows x 2 columns]

# %%
# Reading data from 3rd stock
l_returns = pd.read_csv("l_historical.csv", index_col = "Date", parse_dates=True)
l_returns
# Out:
#            Symbol  Close
# Date
# 2018-01-02      L  57.99
# 2018-01-03      L  57.41
# 2018-01-04      L  57.42
# 2018-01-05      L  57.42
# 2018-01-08      L  56.86
# ...           ...    ...
# 2019-12-20      L  67.90
# 2019-12-23      L  67.68
# 2019-12-24      L  67.67
# 2019-12-27      L  67.78
# 2019-12-30      L  67.33
#
# [501 rows x 2 columns]

# %%
# Combine all stocks in a single DataFrame
all_stocks = [otex_returns, l_returns]
all_stock_data_df = shop_returns[['Close']].rename(columns={'Close': shop_returns['Symbol'][0]})
i = 0
while i < len(all_stocks):
    all_stock_data_df[all_stocks[i]['Symbol'][0]] = all_stocks[i]['Close'].values
    i+=1

# %%
all_stock_data_df
# Out:
#               SHOP   OTEX      L
# Date
# 2018-01-02  132.06  43.58  57.99
# 2018-01-03  135.15  43.07  57.41
# 2018-01-04  137.46  42.91  57.42
# 2018-01-05  137.26  42.57  57.42
# 2018-01-08  139.51  42.16  56.86
# ...            ...    ...    ...
# 2019-12-20  513.22  58.68  67.90
# 2019-12-23  511.62  57.89  67.68
# 2019-12-24  525.39  57.44  67.67
# 2019-12-27  534.76  57.70  67.78
# 2019-12-30  517.79  57.19  67.33
#
# [501 rows x 3 columns]

# %%
# Calculate daily returns
all_stock_portfolio_returns = all_stock_data_df.pct_change().dropna()
# Display sample data
all_stock_portfolio_returns
# Out:
#                 SHOP      OTEX         L
# Date
# 2018-01-03  0.023398 -0.011703 -0.010002
# 2018-01-04  0.017092 -0.003715  0.000174
# 2018-01-05 -0.001455 -0.007924  0.000000
# 2018-01-08  0.016392 -0.009631 -0.009753
# 2018-01-09 -0.011254 -0.000712  0.008969
# ...              ...       ...       ...
# 2019-12-20 -0.005503  0.024441  0.003547
# 2019-12-23 -0.003118 -0.013463 -0.003240
# 2019-12-24  0.026915 -0.007773 -0.000148
# 2019-12-27  0.017834  0.004526  0.001626
# 2019-12-30 -0.031734 -0.008839 -0.006639
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
total_portfolio_returns = all_stock_portfolio_returns['SHOP']*weights[0] + all_stock_portfolio_returns['OTEX']*weights[1] + all_stock_portfolio_returns['L']*weights[2] 
# Display sample data
total_portfolio_returns
# Out:
# Date
# 2018-01-03    0.000565
# 2018-01-04    0.004517
# 2018-01-05   -0.003126
# 2018-01-08   -0.000997
# 2018-01-09   -0.000999
#                 ...
# 2019-12-20    0.007495
# 2019-12-23   -0.006607
# 2019-12-24    0.006331
# 2019-12-27    0.007995
# 2019-12-30   -0.015737
# Length: 500, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
all_stock_portfolio_returns['Total_portfolio_returns'] = total_portfolio_returns
all_stock_portfolio_returns
# Out:
#                 SHOP      OTEX         L  Total_portfolio_returns
# Date
# 2018-01-03  0.023398 -0.011703 -0.010002                 0.000565
# 2018-01-04  0.017092 -0.003715  0.000174                 0.004517
# 2018-01-05 -0.001455 -0.007924  0.000000                -0.003126
# 2018-01-08  0.016392 -0.009631 -0.009753                -0.000997
# 2018-01-09 -0.011254 -0.000712  0.008969                -0.000999
# ...              ...       ...       ...                      ...
# 2019-12-20 -0.005503  0.024441  0.003547                 0.007495
# 2019-12-23 -0.003118 -0.013463 -0.003240                -0.006607
# 2019-12-24  0.026915 -0.007773 -0.000148                 0.006331
# 2019-12-27  0.017834  0.004526  0.001626                 0.007995
# 2019-12-30 -0.031734 -0.008839 -0.006639                -0.015737
#
# [500 rows x 4 columns]

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annualized_std = all_stock_portfolio_returns['Total_portfolio_returns'].std()*np.sqrt(252)

# %%
annualized_std
# Out:
# 0.2167936807134585

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling_portfolio_std = all_stock_portfolio_returns.rolling(window=21).std()
# Plot rolling standard deviation
sns.set(font_scale = 2)
sns.set_style("whitegrid")
fig, ax= plt.subplots(figsize=(20,20))
sns.lineplot(ax=ax, data=rolling_portfolio_std, linewidth = 2.5)
plt.legend(labels= [x for x in rolling_portfolio_std.columns], fontsize = 20)

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
my_portfolio_corr = all_stock_portfolio_returns.corr()
# # Plot rolling Corr
sns.set(font_scale = 2)
sns.set_style("whitegrid")
mask = np.triu(np.ones_like(my_portfolio_corr, dtype=bool))
fig, ax= plt.subplots(figsize=(20,20))
cmap = sns.color_palette("mako", as_cmap=True)
sns.heatmap(ax=ax, data=my_portfolio_corr, cmap=cmap, mask=mask, vmax=1, vmin=-1, square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
portfolio_corr
# Out:
#                              SHOP      OTEX         L  Total_portfolio_returns
# SHOP                     1.000000  0.398427  0.127501                 0.913094
# OTEX                     0.398427  1.000000  0.181266                 0.672637
# L                        0.127501  0.181266  1.000000                 0.390044
# Total_portfolio_returns  0.913094  0.672637  0.390044                 1.000000

# %%
all_stock_portfolio_returns
# Out:
#                 SHOP      OTEX         L  Total_portfolio_returns
# Date
# 2018-01-03  0.023398 -0.011703 -0.010002                 0.000565
# 2018-01-04  0.017092 -0.003715  0.000174                 0.004517
# 2018-01-05 -0.001455 -0.007924  0.000000                -0.003126
# 2018-01-08  0.016392 -0.009631 -0.009753                -0.000997
# 2018-01-09 -0.011254 -0.000712  0.008969                -0.000999
# ...              ...       ...       ...                      ...
# 2019-12-20 -0.005503  0.024441  0.003547                 0.007495
# 2019-12-23 -0.003118 -0.013463 -0.003240                -0.006607
# 2019-12-24  0.026915 -0.007773 -0.000148                 0.006331
# 2019-12-27  0.017834  0.004526  0.001626                 0.007995
# 2019-12-30 -0.031734 -0.008839 -0.006639                -0.015737
#
# [500 rows x 4 columns]

# %%
tsx_daily_returns
# Out:
#               TSX_60
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709
# ...              ...
# 2019-12-20  0.003188
# 2019-12-23  0.000600
# 2019-12-24  0.003003
# 2019-12-27 -0.000695
# 2019-12-30 -0.004057
#
# [1817 rows x 1 columns]

# %%
total_portfolio_and_tsx_returns = all_stock_portfolio_returns[['Total_portfolio_returns']].join(tsx_daily_returns)

# %%
total_portfolio_and_tsx_returns
# Out:
#             Total_portfolio_returns    TSX_60
# Date
# 2018-01-03                 0.000565  0.003774
# 2018-01-04                 0.004517  0.002528
# 2018-01-05                -0.003126 -0.003869
# 2018-01-08                -0.000997 -0.001944
# 2018-01-09                -0.000999  0.000097
# ...                             ...       ...
# 2019-12-20                 0.007495  0.003188
# 2019-12-23                -0.006607  0.000600
# 2019-12-24                 0.006331  0.003003
# 2019-12-27                 0.007995 -0.000695
# 2019-12-30                -0.015737 -0.004057
#
# [500 rows x 2 columns]

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
# Calculate covariance of a single portfolio
portfolio_cov = total_portfolio_and_tsx_returns.cov()['Total_portfolio_returns']

# Calculate variance of S&P TSX
tsx_var = total_portfolio_and_tsx_returns['TSX_60'].var()
# Computing beta
res_portfolio = stats.linregress(total_portfolio_and_tsx_returns['Total_portfolio_returns'].values,total_portfolio_and_tsx_returns['TSX_60'].values)
portfolio_beta = res_portfolio.slope
# Plot beta trend
rolling_covariance_portfolio = total_portfolio_and_tsx_returns['Total_portfolio_returns'].rolling(window=60).cov(total_portfolio_and_tsx_returns['TSX_60'])
rolling_variance_tsx = total_portfolio_and_tsx_returns['TSX_60'].rolling(window=60).var()
rolling_beta_portfolio = rolling_covariance_portfolio / rolling_variance_tsx
sns.set(font_scale = 2)
sns.set_style("whitegrid")
fig, ax= plt.subplots(figsize=(20,20))
p = sns.lineplot(ax=ax, data=rolling_beta_portfolio,linewidth = 2.5).set_title('60 Day Rolling Beta Vs. TSX 60')

# %%
portfolio_beta
# Out:
# 0.22654257075310544

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
#Assuming risk free rate of 2%
sharpe_ratios_portfolio = ((all_stock_portfolio_returns.mean() * 252) - 0.02) / (all_stock_portfolio_returns.std() * np.sqrt(252))
sharpe_ratios_portfolio
# Out:
# SHOP                       1.614590
# OTEX                       0.650546
# L                          0.438824
# Total_portfolio_returns    1.531247
# dtype: float64

# %%
sharpe_df_portfolio = pd.DataFrame(sharpe_ratios_portfolio).reset_index().rename(columns={'index':'Stock', 0:'Sharpe_Ratio'})
sharpe_df_portfolio
# Out:
#                      Stock  Sharpe_Ratio
# 0                     SHOP      1.614590
# 1                     OTEX      0.650546
# 2                        L      0.438824
# 3  Total_portfolio_returns      1.531247

# %%
# Visualize the sharpe ratios as a bar plot
sns.set(font_scale = 2)
sns.set_style("whitegrid")
fig, ax= plt.subplots(figsize=(20,20))
sns.barplot(ax=ax, x='Stock', y='Sharpe_Ratio', data=sharpe_df_portfolio)
plt.legend(labels= [x for x in all_stock_portfolio_returns.columns], fontsize = 20)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %% [markdown]
# ## It does great considering that it is somewhat "Diversified", but does not outperform Shopify, doubt it will given its run
